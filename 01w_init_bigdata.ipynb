# %% [markdown]
# <a href="https://colab.research.google.com/github/dbstj118/2026_2-1_BDA/blob/main/01w_init_bigdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 간단한 데이터 시각화
# - matplotlib 활용 데이터 시각화
# - 한글 처리

# %%
import sys
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]'

# %%
import site
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.12/dist-packages']

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.10.0'

# %% [markdown]
# - 그림을 선명하게

# %%
# %config inlineBackend.figure_format = 'retina'

# %% [markdown]
# - 한글 폰트 설치

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 39.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# - 한글 폰트 메모리에 옮기기

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt
plt.title('데이터 시각화 한글 준비와 기본 직선 그리기')
plt.plot([10,5,20,30])
plt.show()

# %%
import pandas as pd
pop = pd.read_csv('popmonth.csv', encoding = 'cp949', index_col=0, thousands=',')
pop
# Out:
#                        2026년02월_총인구수  2026년02월_세대수  2026년02월_세대당 인구  \
# 행정구역
# 전국  (1000000000)            51106229      24350797             2.10
# 서울특별시  (1100000000)          9304129       4512818             2.06
# 부산광역시  (2600000000)          3239016       1576653             2.05
# 대구광역시  (2700000000)          2351461       1115161             2.11
# 인천광역시  (2800000000)          3054367       1404284             2.18
# 광주광역시  (2900000000)          1389235        659087             2.11
# 대전광역시  (3000000000)          1441405        699675             2.06
# 울산광역시  (3100000000)          1089835        499950             2.18
# 세종특별자치시  (3600000000)         391240        165449             2.36
# 경기도  (4100000000)           13742072       6138755             2.24
# 강원특별자치도  (5100000000)        1506699        769508             1.96
# 충청북도  (4300000000)           1596816        799712             2.00
# 충청남도  (4400000000)           2136064       1064222             2.01
# ...

# %%
pop.index
# Out:
# Index(['전국  (1000000000)', '서울특별시  (1100000000)', '부산광역시  (2600000000)',
#        '대구광역시  (2700000000)', '인천광역시  (2800000000)', '광주광역시  (2900000000)',
#        '대전광역시  (3000000000)', '울산광역시  (3100000000)', '세종특별자치시  (3600000000)',
#        '경기도  (4100000000)', '강원특별자치도  (5100000000)', '충청북도  (4300000000)',
#        '충청남도  (4400000000)', '전북특별자치도  (5200000000)', '전라남도  (4600000000)',
#        '경상북도  (4700000000)', '경상남도  (4800000000)', '제주특별자치도  (5000000000)'],
#       dtype='object', name='행정구역')

# %%
pop.index[1]
# Out:
# '서울특별시  (1100000000)'

# %%
pop.index[0]
# Out:
# '전국  (1000000000)'

# %%
pop.columns = ['총인구수','세대수','세대당인구','남자인구수','여자인구수','남여비율']
pop.head()
# Out:
#                          총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 행정구역
# 전국  (1000000000)     51106229  24350797   2.10  25429357  25676872  0.99
# 서울특별시  (1100000000)   9304129   4512818   2.06   4482300   4821829  0.93
# 부산광역시  (2600000000)   3239016   1576653   2.05   1574040   1664976  0.95
# 대구광역시  (2700000000)   2351461   1115161   2.11   1151654   1199807  0.96
# 인천광역시  (2800000000)   3054367   1404284   2.18   1525266   1529101  1.00

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#              총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 전국       51106229  24350797   2.10  25429357  25676872  0.99
# 서울특별시     9304129   4512818   2.06   4482300   4821829  0.93
# 부산광역시     3239016   1576653   2.05   1574040   1664976  0.95
# 대구광역시     2351461   1115161   2.11   1151654   1199807  0.96
# 인천광역시     3054367   1404284   2.18   1525266   1529101  1.00
# 광주광역시     1389235    659087   2.11    685321    703914  0.97
# 대전광역시     1441405    699675   2.06    718084    723321  0.99
# 울산광역시     1089835    499950   2.18    561965    527870  1.06
# 세종특별자치시    391240    165449   2.36    194784    196456  0.99
# 경기도      13742072   6138755   2.24   6899712   6842360  1.01
# 강원특별자치도   1506699    769508   1.96    757648    749051  1.01
# 충청북도      1596816    799712   2.00    813918    782898  1.04
# 충청남도      2136064   1064222   2.01   1097210   1038854  1.06
# 전북특별자치도   1721941    869571   1.98    858094    863847  0.99
# ...

# %%
pop.index
# Out:
# Index(['전국', '서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원특별자치도', '충청북도', '충청남도', '전북특별자치도', '전라남도', '경상북도',
#        '경상남도', '제주특별자치도'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
