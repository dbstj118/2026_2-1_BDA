# %% [markdown]
# <a href="https://colab.research.google.com/github/dbstj118/2026_2-1_BDA/blob/main/09w_data_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #09 파이썬 데이터 시각화

# %% [markdown]
# ##1. 산점도와 막대 그래프

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# %config inlineBackend.figure_format = 'retina'
# Out:
# Collecting koreanize-matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from koreanize-matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize-matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 75.2 MB/s eta 0:00:00
# Installing collected packages: koreanize-matplotlib
# Successfully installed koreanize-matplotlib-0.1.1

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (5,3)

# %%
#3과 5가 x, 7과 10이 y
plt.scatter([3,5],[7,10])
plt.show()

# %%
plt.scatter(range(1,5),range(5,9))
plt.show()

# %%
plt.scatter(range(3,8),range(13,18))
plt.show()

# %% [markdown]
# ###기니피그

# %%
# !pip show pydataset
# Out:
# WARNING: Package(s) not found: pydataset

# %%
# !pip install pydataset
# Out:
# Collecting pydataset
#   Downloading pydataset-0.2.0.tar.gz (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 72.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pydataset) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pydataset) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pydataset) (1.17.0)
# Building wheels for collected packages: pydataset
#   Building wheel for pydataset (setup.py) ... done
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=29717e870d01ee86af9469bfb745aa50573db9e1eacd02239f0e80c50838fcbe
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# Installing collected packages: pydataset
# Successfully installed pydataset-0.2.0

# %%
from pydataset import data
tg = data('ToothGrowth')
tg.head()
# Out:
# initiated datasets repo at: /root/.pydataset/
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %%
tg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
tg.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000

# %%
plt.scatter(tg.dose,tg.len)
plt.title("기니피그의 비타민과 치아성장 관계")
plt.xlabel("비타민 용량")
plt.ylabel("치아성장 세포길이")
plt.show()

# %%
import seaborn as sns
sns.scatterplot(data=tg, x='dose', y='len', hue='supp') #자동 색상 구분
plt.title("기니피그의 비타민과 치아성장 관계")
plt.xlabel("비타민 용량")
plt.ylabel("치아성장 세포길이")
plt.show()

# %%
import seaborn as sns
sns.boxplot(tg,x='dose',y='len',hue='supp')
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.stripplot(tg,x='dose',y='len',hue='supp')
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.stripplot(tg,x='dose',y='len',hue='supp', dodge=True)
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(tg,x='dose',y='len',hue='supp')
sns.stripplot(tg,x='dose',y='len',hue='supp',dodge=True, alpha=.4)
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(tg,x='dose',y='len',hue='supp')
sns.stripplot(tg,x='dose',y='len',hue='supp',dodge=True, alpha=.4)
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement',loc='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(tg,x='dose',y='len',hue='supp')
sns.stripplot(tg,x='dose',y='len',hue='supp',dodge=True, alpha=.4)
plt.title('기니피그 치아 성장')
plt.xlabel('치아 길이(mm)')
plt.ylabel('용량(mg/day)')
plt.legend(title='Supplement',loc='lower center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###선 그리기 함수 plot()

# %%
import matplotlib.pyplot as plt
plt.plot(range(10,16))

# %%
plt.plot(range(10,16),linestyle='--')

# %%
import numpy as np
x = np.arange(-5,5.1,0.1)
plt.plot(x,x**2,ls=":")
plt.xlabel('$x$')
plt.ylabel('$y = x^2$')
# Out:
# Text(0, 0.5, '$y = x^2$')

# %%
#실행 결과가 보기 편해서 Ai 도움 받아서 추가한 코드

import matplotlib.pyplot as plt

x = range(0, 11)

plt.plot(x, [4]*len(x), linestyle='dashdot', color='red', label='dashdot') ##-.
plt.plot(x, [3]*len(x), linestyle='dashed', color='green', label='dashed') ##--
plt.plot(x, [2]*len(x), linestyle='dotted', color='orange', label='dotted') ##:
plt.plot(x, [1]*len(x), linestyle='solid', color='blue', label='solid') ##-

plt.yticks([1, 2, 3, 4], ['solid', 'dotted', 'dashed', 'dashdot'])
plt.xlim(0, 10)
plt.ylim(0, 5)

plt.grid(True)
plt.show()

# %% [markdown]
# ###내장 데이터 AirPassengers

# %%
from pydataset import data
airpsngr = data('AirPassengers')
airpsngr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 1 to 144
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time           144 non-null    float64
#  1   AirPassengers  144 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 3.4 KB

# %%
plt.plot(airpsngr.time, airpsngr.AirPassengers, color = 'darkgreen')
plt.xlabel('연도')
plt.ylabel('승객수')
# Out:
# Text(0, 0.5, '승객수')

# %% [markdown]
# ###다양한 선 종류와 마커 종류

# %%
import matplotlib.pyplot as plt

# 데이터 준비
x = [1,2,3,4]
y1 = [1,4,9,16]
y2 = [2,4,6,8]
y3 = [3,6,8,12]
y4 = [4,8,12,16]

#선 스타일별로 그래프 그리기
plt.plot(x, y1, linestyle='-', label='Solid line')
plt.plot(x, y2, linestyle='--', label='Dashed line')
plt.plot(x, y3, linestyle=':', label='Dotted line')
plt.plot(x, y4, linestyle='-.', label='Dash-dot line')

#그래프 제목과 축 레이블
plt.title("선 종류(Line Styles in Matplotlib)")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

#범례 추가
plt.legend()

#그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터 준비
x = [1,2,3,4]
y1 = [1,4,9,16]
y2 = [2,3,4,5]
y3 = [2,2,3,3]
y4 = [3,1,4,2]
y5 = [4,5,6,8]

#선 스타일별로 그래프 그리기
plt.plot(x, y1, marker='o', label='Circle')
plt.plot(x, y2, marker='^', label='Triangle_up')
plt.plot(x, y3, marker='s', label='Square')
plt.plot(x, y4, marker='*', label='Star')
plt.plot(x, y5, marker=',', label='Pixel')

#그래프 제목과 축 레이블
plt.title("Marker Styles in Matplotlib")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

#범례 추가
plt.legend()

#그래프 보여주기
plt.show()

# %%
plt.plot(range(1,5), range(5,9), ls=' ', marker='o')
plt.show()

# %% [markdown]
# ###비타민 용량과 세포길이

# %%
vc = tg[tg.supp == "VC"][['len','dose']]
oj = tg[tg.supp == "OJ"][['len','dose']]

plt.plot(vc.dose, vc.len, color='cyan', marker='o', label="아스코르브산(VC)", lw=.7)
plt.plot(oj.dose, oj.len, color='deeppink', marker='^', ls=':', label="오렌지 주스(OJ)", lw=.7, alpha=.5)
plt.title("기니피그의 비타민과 자아성찰 관계")
plt.xlabel("비타민 용량")
plt.ylabel("치아성장 세포길이")
plt.legend()

# %% [markdown]
# ###범례의 좌측 상단 모서리 위치를 좌표로 지정

# %%
plt.plot(vc.dose, vc.len, color='cyan', marker='o', label="아스코르브산(VC)", lw=.7)
plt.plot(oj.dose, oj.len, color='deeppink', marker='^', ls=':', label="오렌지 주스(OJ)", lw=.7, alpha=.5)
plt.title("기니피그의 비타민과 자아성찰 관계")
plt.xlabel("비타민 용량")
plt.ylabel("치아성장 세포길이")
plt.legend(loc='lower right')

# %% [markdown]
# ###bar()

# %%
import matplotlib.pyplot as plt
point = [99,65,79,80,90]
name = ["영희", "철수", "윤철", "미현", "현수"]
plt.bar(name, point, color = ["blue","chartreuse","purple","grey","orange"])
plt.title('데이터분석 점수')
# Out:
# Text(0.5, 1.0, '데이터분석 점수')

# %% [markdown]
# ###barh()
# 막대 그래프 가로

# %%
import matplotlib.pyplot as plt
point = [99,65,79,80,90]
name = ["영희", "철수", "윤철", "미현", "현수"]
plt.barh(name, point, height=.6, color = ["blue","chartreuse","purple","grey","orange"])
plt.title('데이터분석 점수')
plt.xlabel('점수')
plt.ylabel('이름')
# Out:
# Text(0, 0.5, '이름')

# %% [markdown]
# ###내장 데이터 LifeCycleSavings

# %%
from pydataset import data
lcs = data('LifeCycleSavings')
lcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Australia to Malaysia
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr      50 non-null     float64
#  1   pop15   50 non-null     float64
#  2   pop75   50 non-null     float64
#  3   dpi     50 non-null     float64
#  4   ddpi    50 non-null     float64
# dtypes: float64(5)
# memory usage: 2.3+ KB

# %%
lcs.tail()
# Out:
#              sr  pop15  pop75     dpi   ddpi
# Zambia    18.56  45.25   0.56  138.33   5.14
# Jamaica    7.72  41.12   1.73  380.47  10.23
# Uruguay    9.24  28.13   2.72  766.54   1.88
# Libya      8.89  43.69   2.07  123.58  16.71
# Malaysia   4.71  47.20   0.66  242.69   5.08

# %%
df = lcs[:5][['pop15']]
df
# Out:
#            pop15
# Australia  29.35
# Austria    23.32
# Belgium    23.80
# Bolivia    41.89
# Brazil     42.19

# %%
plt.bar(df.index,df.pop15)
plt.title("국가별 15세미만 인구비율")
plt.xlabel("국가")
plt.ylabel("15세미만 인구비율(%)")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=lcs,x='dpi',y='sr',hue='pop15',palette='viridis',size='pop75',sizes=(20,200))
plt.title("저축률과 소득, 나이 구조 비교")
plt.xlabel("dpi")
plt.ylabel("sr")
plt.tight_layout()
plt.show()

# %%
lcs[lcs.index.str.contains('Korea')]
# Out:
#          sr  pop15  pop75     dpi  ddpi
# Korea  3.98  41.74   0.91  207.68  5.81

# %%
lcs[lcs.index.isin('Korea')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_714/3934126331.py in <cell line: 0>()
# ----> 1 lcs[lcs.index.isin('Korea')]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in isin(self, values, level)
#    6609         if level is not None:
#    6610             self._validate_index_level(level)
# -> 6611         return algos.isin(self._values, values)
#    6612
#    6613     def _get_string_slice(self, key: str_t):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/algorithms.py in isin(comps, values)
#     475         )
#     476     if not is_list_like(values):
# --> 477         raise TypeError(
#     478             "only list-like objects are allowed to be passed "
#     479             f"to isin(), you passed a `{type(values).__name__}`"
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a `str`

# %%
lcs[lcs.index.isin(['Korea','Korea'])]
# Out:
#          sr  pop15  pop75     dpi  ddpi
# Korea  3.98  41.74   0.91  207.68  5.81

# %%
lcs[lcs.index.isin(['Korea','Japan'])]
# Out:
#           sr  pop15  pop75      dpi  ddpi
# Japan  21.10  27.01   1.91  1257.28  8.21
# Korea   3.98  41.74   0.91   207.68  5.81

# %% [markdown]
# ###데이터셋 mtcars

# %%
from pydataset import data
mtc = data('mtcars')
mtc.mpg.quantile([0.,.25,.50,.75,1])
# Out:
# 0.00    10.400
# 0.25    15.425
# 0.50    19.200
# 0.75    22.800
# 1.00    33.900
# Name: mpg, dtype: float64

# %%
mtc.mpg.describe()[3:]
# Out:
# min    10.400
# 25%    15.425
# 50%    19.200
# 75%    22.800
# max    33.900
# Name: mpg, dtype: float64

# %%
mtc_cyl = mtc.cyl.value_counts()
mtc_cyl
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
plt.bar(mtc_cyl.index, mtc_cyl)
plt.title("자동차 실린더(기통) 분포")
plt.xlabel("실린더 수")
plt.ylabel("자동차 수")
# Out:
# Text(0, 0.5, '자동차 수')

# %%
mtc.cyl.value_counts().plot.bar()
plt.xticks(rotation=360)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '8'), Text(1, 0, '4'), Text(2, 0, '6')])

# %%
import seaborn as sns
sns.countplot(mtc, x='gear')
# Out:
# <Axes: xlabel='gear', ylabel='count'>

# %%
import seaborn as sns
ax = sns.countplot(data = mtc, x='gear', order = mtc.gear.value_counts().index)

for p in ax.patches:
  height = p.get_height() #빈도 수
  ax.text(x = (p.get_x() + p.get_width()/2.), y = (height + .2),
          s = int(height), ha = 'center', size=12, color='blue')

ax.set_ylim(0,17) #y축의 범위를 0부터 17까지로 설정
plt.show()

# %% [markdown]
# ##2. 상자그림과 히스토그램

# %% [markdown]
# ###상자그림

# %%
from pydataset import data
mtc = data('mtcars')
mtc.mpg.quantile([0., .25, .50, .75, 1])
# Out:
# 0.00    10.400
# 0.25    15.425
# 0.50    19.200
# 0.75    22.800
# 1.00    33.900
# Name: mpg, dtype: float64

# %%
mtc.mpg.describe()[3:]
# Out:
# min    10.400
# 25%    15.425
# 50%    19.200
# 75%    22.800
# max    33.900
# Name: mpg, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(mtc.mpg)
plt.show()

# %%
mtc.mpg.plot.box()
# Out:
# <Axes: >

# %%
import numpy as np

plt.boxplot([mtc.disp, mtc.hp])
plt.title("배기량과 마력 비교(boxplot)")
plt.xticks(ticks = np.arange(1,3), labels = ["배기량","마력"])
plt.show()

# %%
mtc[['disp','hp']].plot(title="배기량과 마력 비교(boxplot)", kind='box')
plt.xticks(ticks = np.arange(1,3), labels = ["배기량","마력"])
plt.show()

# %% [markdown]
# ###히스토그램

# %%
plt.hist(mtc.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.mpg,edgecolor='black')
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt,edgecolor='white')
# Out:
# (array([3., 3., 3., 3., 9., 7., 1., 0., 0., 3.]),
#  array([1.513 , 1.9041, 2.2952, 2.6863, 3.0774, 3.4685, 3.8596, 4.2507,
#         4.6418, 5.0329, 5.424 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt, bins=5, edgecolor='white')
# Out:
# (array([ 6.,  6., 16.,  1.,  3.]),
#  array([1.513 , 2.2952, 3.0774, 3.8596, 4.6418, 5.424 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
plt.hist(mtc.wt, bins = np.arange(1.5,5.6,0.5), edgecolor='white')
# Out:
# (array([4., 4., 4., 9., 7., 1., 0., 3.]),
#  array([1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(mtc.wt, bins = [1.5,2.5,4.5,5.5], edgecolor='white')
# Out:
# (array([ 8., 21.,  3.]),
#  array([1.5, 2.5, 4.5, 5.5]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(mtc.wt, bins = [1.5,2.5,4.5,5.5], density=True, edgecolor='white')
# Out:
# (array([0.25    , 0.328125, 0.09375 ]),
#  array([1.5, 2.5, 4.5, 5.5]),
#  <BarContainer object of 3 artists>)
